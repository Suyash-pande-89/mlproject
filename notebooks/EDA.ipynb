# %% [markdown]
# Import all required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings

# %%
#Read data file
df = pd.read_csv("data/StudentsPerformance.csv")

# %%
print(df.head())
df.shape
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# (1000, 8)

# %%
#Check missing or na values
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# Observation 1 : No missing value

# %%
#check duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Observation 2: No duplicate values

# %%
#Number of unque values of each column
print(df.nunique(),"\n ==================\n",df.size,"\n ==================\n",df.count())
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64
# ...
#  8000
# ...
#  gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
df[["gender","lunch"]].value_counts()
# Out:
# gender  lunch
# female  standard        329
# male    standard        316
# female  free/reduced    189
# male    free/reduced    166
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
numeric_variables = [feat for feat in df.columns if df[feat].dtypes == "int64"]
categorical_variables = [feat for feat in df.columns if df[feat].dtypes == "object"]
print ("There are {} numeric features and {} categorical features.\n They are \nNumeric features - {}\nCategorical features - {}".format(len(numeric_variables),len(categorical_variables),numeric_variables,categorical_variables))
# Out:
# There are 3 numeric features and 5 categorical features.
#  They are
# Numeric features - ['math score', 'reading score', 'writing score']
# Categorical features - ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %%
#Access top6 rows and bttom 7 rows in dataframe

pd.concat([df.iloc[:6],df.iloc[-7:]],ignore_index=True)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group D           bachelor's degree  free/reduced
# 7     male        group A                 high school      standard
# 8   female        group E             master's degree      standard
# 9     male        group C                 high school  free/reduced
# 10  female        group C                 high school  free/reduced
# 11  female        group D                some college      standard
# 12  female        group D                some college  free/reduced
#
# ...

# %%
#Add ing column for total score and mean score
df['total_score'] = df['math score'] + df['reading score']+ df['writing score']
df['mean_score'] = round(df['total_score']/3)

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...
